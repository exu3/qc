# %% [markdown]
# # Week 1 Day 1 lab

# %% [markdown]
# ## Topics we will cover:
# Printing

# %% [markdown]
# ## Printing

# %%
# Block 1 - Welcome to coding! Try printing "hello world"
print('hello world')
# Out:
# hello world

# %%
# Block 2 - Try printing your name! 
# Print “_____, welcome to quantum camp” where the blank is your name.
print('lol blank person, welcome to quantum camp')
# Out:
# lol blank person, welcome to quantum camp

# %%
# BLock 3 - Copy the code from the slide into this block. What output do you get? Is this what you expected?

# %%
# Block 4 - Try printing your name and age using two print statements
